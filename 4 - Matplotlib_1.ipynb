# %% [markdown]
# # Matplotlip

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
#grafikleri gösterecek
# %matplotlib inline

# %%
yasListesi = [10,20,30,40,50,60,70,75]
kiloListesi = [20,30,80,85,86,70,70,75]

# %%
numpyYasListesi = np.array(yasListesi)
numpyKiloListesi = np.array(kiloListesi)

# %%
# plot(x,y, "green")
plt.plot(numpyYasListesi,numpyKiloListesi,"g")

# %%
#etiket
plt.plot(numpyYasListesi,numpyKiloListesi,"g")
plt.xlabel("Yas")
plt.ylabel("Kilo")
#plt.show() demedik çünkü matplotlib inline kullanıyorum
# Out:
# Text(0, 0.5, 'Kilo')

# %%
#0 ile 10 arasında 20 adet sayı
numpyDizisi1 = np.linspace(0,10,20)
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi1 ** 3
numpyDizisi2
# Out:
# array([0.00000000e+00, 1.45793847e-01, 1.16635078e+00, 3.93643388e+00,
#        9.33080624e+00, 1.82242309e+01, 3.14914711e+01, 5.00072897e+01,
#        7.46464499e+01, 1.06283715e+02, 1.45793847e+02, 1.94051611e+02,
#        2.51931768e+02, 3.20309083e+02, 4.00058318e+02, 4.92054235e+02,
#        5.97171599e+02, 7.16285173e+02, 8.50269719e+02, 1.00000000e+03])

# %%
plt.plot(numpyDizisi1,numpyDizisi2,"r--")
plt.xlabel("1. dizi")
plt.ylabel("2. dizi")
# Out:
# Text(0, 0.5, '2. dizi')

# %%
plt.plot(numpyDizisi1,numpyDizisi2,"r.-")
plt.xlabel("1. dizi")
plt.ylabel("2. dizi")
# Out:
# Text(0, 0.5, '2. dizi')

# %% [markdown]
# # subplot (kac sıra,kac grafik,kacıncıyı ciz) 2 grafik yapma

# %%
plt.subplot(1,2,1) # birinci grafik YANYANA
plt.plot(numpyDizisi1,numpyDizisi2,"r*-")
plt.xlabel("1. dizi")
plt.ylabel("2. dizi")
plt.subplot(1,2,2) # ikinici grafik
plt.plot(numpyDizisi2,numpyDizisi1,"b.-")
plt.xlabel("2. dizi")
plt.ylabel("1. dizi")
# Out:
# Text(0, 0.5, '1. dizi')

# %% [markdown]
# ## OBJE KULLANARAK YAPMA

# %%
benimFigure = plt.figure()
figureAxes = benimFigure.add_axes([0.2,0.2,0.9,0.9]) # shift + tab
#                                grefaik konumu, width , height                                   
figureAxes.plot(numpyDizisi1,numpyDizisi2,"r")
figureAxes.set_xlabel("X ekseni veri ismi")
figureAxes.set_ylabel("X ekseni veri ismi")
figureAxes.set_title("Grafik Başlığı")
plt.show()

# %% [markdown]
# ## -----------

# %%
yeniFigur = plt.figure()

yeniEksen = yeniFigur.add_axes([0.1,0.1,0.9,0.9])
#label etiket verir
yeniEksen.plot(numpyDizisi1,numpyDizisi2, label = "numpyDizisi ** 2")
yeniEksen.legend()

# %%
#2 adet veri
#figsize boyutu ayarladı
#yeniFigur = plt.figure(figsize = (3,3))

#dpi boyutu
yeniFigur = plt.figure(dpi = 100)

yeniEksen = yeniFigur.add_axes([0.1,0.1,0.9,0.9])
#label etiket verir
yeniEksen.plot(numpyDizisi1,numpyDizisi1 ** 2, label = "numpyDizisi ** 2")
yeniEksen.plot(numpyDizisi1,numpyDizisi1 **3, label = "numpyDizisi ** 3")
#loc pozisyon verir
yeniEksen.legend(loc=1)

# %%
# grafigi kaydetme
yeniFigur.savefig("benimfigur.png",dpi=200)
